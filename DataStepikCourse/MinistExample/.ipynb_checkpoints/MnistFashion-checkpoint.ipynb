# %%
import pandas as pd
import tensorflow as tf
# %load_ext tensorboard

# %%
# !rm -rf ./logs/

# %%
data = pd.read_csv('../fashionmnist/fashion-mnist_train.csv')

# %%
pixels = [f'pixel{i}' for i in range(1,785)]
y = data['label'].values
X = data[pixels].values
X = X/255
X = X.astype(dtype='float32')
y = tf.keras.utils.to_categorical(y,num_classes=10)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=42)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout

# %%
model_lr = Sequential()
model_lr.add( Dense(10, input_shape=(784,),activation='softmax'))
model_lr.compile(optimizer='adam',
                loss='categorical_crossentropy',
                metrics=['accuracy']
                )

# %%
import datetime
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# %%
model_lr_fit = model_lr.fit(
    X_train,
    y_train,
    epochs=10,
    batch_size=32, 
    validation_data=(X_test,y_test),
    callbacks=[tensorboard_callback]
)
# Out:
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/10
# 45000/45000 [==============================] - 8s 172us/step - loss: 0.3930 - accuracy: 0.8631 - val_loss: 0.4216 - val_accuracy: 0.8527
# Epoch 2/10
# 45000/45000 [==============================] - 7s 158us/step - loss: 0.3908 - accuracy: 0.8650 - val_loss: 0.4199 - val_accuracy: 0.8555
# Epoch 3/10
# 45000/45000 [==============================] - 7s 155us/step - loss: 0.3876 - accuracy: 0.8654 - val_loss: 0.4217 - val_accuracy: 0.8529
# Epoch 4/10
# 45000/45000 [==============================] - 7s 163us/step - loss: 0.3852 - accuracy: 0.8653 - val_loss: 0.4170 - val_accuracy: 0.8569
# Epoch 5/10
# 45000/45000 [==============================] - 7s 163us/step - loss: 0.3837 - accuracy: 0.8663 - val_loss: 0.4357 - val_accuracy: 0.8471
# Epoch 6/10
# 45000/45000 [==============================] - 8s 176us/step - loss: 0.3814 - accuracy: 0.8669 - val_loss: 0.4178 - val_accuracy: 0.8543
# Epoch 7/10
# 45000/45000 [==============================] - 8s 168us/step - loss: 0.3803 - accuracy: 0.8676 - val_loss: 0.4246 - val_accuracy: 0.8551
# Epoch 8/10
# 45000/45000 [==============================] - 8s 170us/step - loss: 0.3791 - accuracy: 0.8682 - val_loss: 0.4248 - val_accuracy: 0.8537
# Epoch 9/10
# 45000/45000 [==============================] - 8s 177us/step - loss: 0.3784 - accuracy: 0.8684 - val_loss: 0.4305 - val_accuracy: 0.8539
# Epoch 10/10
# 45000/45000 [==============================] - 8s 169us/step - loss: 0.3747 - accuracy: 0.8690 - val_loss: 0.4318 - val_accuracy: 0.8515

# %%
import matplotlib.pyplot as plt
def plot_history(histories, key='accuracy'):
  plt.figure(figsize=(16,10))

  for name, history in histories:
    val = plt.plot(history.epoch, history.history['val_'+key],
                   '--', label=name.title()+' Val')
    plt.plot(history.epoch, history.history[key], color=val[0].get_color(),
             label=name.title()+' Train')

  plt.xlabel('Epochs')
  plt.ylabel(key.replace('_',' ').title())
  plt.legend()

  plt.xlim([0,max(history.epoch)])


plot_history([('logistic regrission', model_lr_fit)])

# %%
model_mlp = Sequential()
model_mlp.add( Dense(256,input_shape=(784,), activation='relu') )
model_mlp.add( Dropout(0.5))
model_mlp.add( Dense(128, activation='relu') )
model_mlp.add( Dropout(0.5))
model_mlp.add(Dense(10,activation='softmax'))

# %%
28*28
# Out:
# 784
